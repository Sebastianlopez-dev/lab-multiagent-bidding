# %% [markdown]
# # Lab | Multi-agent bidding

# %% [markdown]
# # Multi-agent decentralized speaker selection
#
# This notebook showcases how to implement a multi-agent simulation without a fixed schedule for who speaks when. Instead the agents decide for themselves who speaks. We can implement this by having each agent bid to speak. Whichever agent's bid is the highest gets to speak.
#
# We will show how to do this in the example below that showcases a fictitious presidential debate.

# %% [markdown]
# ## Import LangChain related modules

# %%
# !pip install langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (1.2.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.2 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langchain-openai) (1.4.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langchain-openai) (2.37.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.11.7)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.23.0)
# Requirement already satisfied: anyio in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (4.12.1)
# Requirement already satisfied: certifi in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.7)
# Requirement already satisfied: h11>=0.16 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.14.0)
# Requirement already satisfied: sniffio in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.4.0)
# Requirement already satisfied: regex in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.5.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/basstianlopez/miniconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.5.0)

# %%
from typing import Callable, List

import tenacity
from langchain.output_parsers import RegexParser
from langchain.prompts import PromptTemplate
from langchain.schema import (
    HumanMessage,
    SystemMessage,
)
from langchain_openai import ChatOpenAI

# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ## `DialogueAgent` and `DialogueSimulator` classes
# We will use the same `DialogueAgent` and `DialogueSimulator` classes defined in [Multi-Player Dungeons & Dragons](https://python.langchain.com/en/latest/use_cases/agent_simulations/multi_player_dnd.html).

# %%
class DialogueAgent:
    def __init__(
        self,
        name: str,
        system_message: SystemMessage,
        model: ChatOpenAI,
    ) -> None:
        self.name = name
        self.system_message = system_message
        self.model = model
        self.prefix = f"{self.name}: "
        self.reset()

    def reset(self):
        self.message_history = ["Here is the conversation so far."]

    def send(self) -> str:
        """
        Applies the chatmodel to the message history
        and returns the message string
        """
        message = self.model.invoke(
            [
                self.system_message,
                HumanMessage(content="\n".join(self.message_history + [self.prefix])),
            ]
        )
        return message.content

    def receive(self, name: str, message: str) -> None:
        """
        Concatenates {message} spoken by {name} into message history
        """
        self.message_history.append(f"{name}: {message}")


class DialogueSimulator:
    def __init__(
        self,
        agents: List[DialogueAgent],
        selection_function: Callable[[int, List[DialogueAgent]], int],
    ) -> None:
        self.agents = agents
        self._step = 0
        self.select_next_speaker = selection_function

    def reset(self):
        for agent in self.agents:
            agent.reset()

    def inject(self, name: str, message: str):
        """
        Initiates the conversation with a {message} from {name}
        """
        for agent in self.agents:
            agent.receive(name, message)

        # increment time
        self._step += 1

    def step(self) -> tuple[str, str]:
        # 1. choose the next speaker
        speaker_idx = self.select_next_speaker(self._step, self.agents)
        speaker = self.agents[speaker_idx]

        # 2. next speaker sends message
        message = speaker.send()

        # 3. everyone receives message
        for receiver in self.agents:
            receiver.receive(speaker.name, message)

        # 4. increment time
        self._step += 1

        return speaker.name, message

# %% [markdown]
# ## `BiddingDialogueAgent` class
# We define a subclass of `DialogueAgent` that has a `bid()` method that produces a bid given the message history and the most recent message.

# %%
class BiddingDialogueAgent(DialogueAgent):
    def __init__(
        self,
        name,
        system_message: SystemMessage,
        bidding_template: PromptTemplate,
        model: ChatOpenAI,
    ) -> None:
        super().__init__(name, system_message, model)
        self.bidding_template = bidding_template

    def bid(self) -> str:
        """
        Asks the chat model to output a bid to speak
        """
        prompt = PromptTemplate(
            input_variables=["message_history", "recent_message"],
            template=self.bidding_template,
        ).format(
            message_history="\n".join(self.message_history),
            recent_message=self.message_history[-1],
        )
        bid_string = self.model.invoke([SystemMessage(content=prompt)]).content
        return bid_string

# %% [markdown]
# ## Define participants and debate topic

# %%
character_names = ["Ivan Cepeda", "Abelardo de la Espriella", "Paloma Valencia"]
topic = "transnational high speed rail"
word_limit = 50

# %% [markdown]
# ## Generate system messages

# %%
game_description = f"""Here is the topic for the presidential debate: {topic}.
The presidential candidates are: {', '.join(character_names)}."""

player_descriptor_system_message = SystemMessage(
    content="You can add detail to the description of each presidential candidate."
)


def generate_character_description(character_name):
    character_specifier_prompt = [
        player_descriptor_system_message,
        HumanMessage(
            content=f"""{game_description}
            Please reply with a creative description of the presidential candidate, {character_name}, in {word_limit} words or less, that emphasizes their personalities. 
            Speak directly to {character_name}.
            Do not add anything else."""
        ),
    ]
    character_description = ChatOpenAI(temperature=1.0)(
        character_specifier_prompt
    ).content
    return character_description


def generate_character_header(character_name, character_description):
    return f"""{game_description}
Your name is {character_name}.
You are a presidential candidate.
Your description is as follows: {character_description}
You are debating the topic: {topic}.
Your goal is to be as creative as possible and make the voters think you are the best candidate.
"""


def generate_character_system_message(character_name, character_header):
    return SystemMessage(
        content=(
            f"""{character_header}
You will speak in the style of {character_name}, and exaggerate their personality.
You will come up with creative ideas related to {topic}.
Do not say the same things over and over again.
Speak in the first person from the perspective of {character_name}
For describing your own body movements, wrap your description in '*'.
Do not change roles!
Do not speak from the perspective of anyone else.
Speak only from the perspective of {character_name}.
Stop speaking the moment you finish speaking from your perspective.
Never forget to keep your response to {word_limit} words!
Do not add anything else.
    """
        )
    )


character_descriptions = [
    generate_character_description(character_name) for character_name in character_names
]
character_headers = [
    generate_character_header(character_name, character_description)
    for character_name, character_description in zip(
        character_names, character_descriptions
    )
]
character_system_messages = [
    generate_character_system_message(character_name, character_headers)
    for character_name, character_headers in zip(character_names, character_headers)
]

# %%
for (
    character_name,
    character_description,
    character_header,
    character_system_message,
) in zip(
    character_names,
    character_descriptions,
    character_headers,
    character_system_messages,
):
    print(f"\n\n{character_name} Description:")
    print(f"\n{character_description}")
    print(f"\n{character_header}")
    print(f"\n{character_system_message.content}")
# Out:
# Ivan Cepeda Description:
#
# Ivan Cepeda, a passionate advocate for social justice and human rights, your unwavering dedication and strong principles make you a formidable leader. Your empathy and commitment to equality resonate deeply with the people. Show us your vision for a better future through transnational high speed rail.
#
# Here is the topic for the presidential debate: transnational high speed rail.
# The presidential candidates are: Ivan Cepeda, Abelardo de la Espriella, Paloma Valencia.
# Your name is Ivan Cepeda.
# You are a presidential candidate.
# Your description is as follows: Ivan Cepeda, a passionate advocate for social justice and human rights, your unwavering dedication and strong principles make you a formidable leader. Your empathy and commitment to equality resonate deeply with the people. Show us your vision for a better future through transnational high speed rail.
# You are debating the topic: transnational high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# Here is the topic for the presidential debate: transnational high speed rail.
# The presidential candidates are: Ivan Cepeda, Abelardo de la Espriella, Paloma Valencia.
# Your name is Ivan Cepeda.
# You are a presidential candidate.
# Your description is as follows: Ivan Cepeda, a passionate advocate for social justice and human rights, your unwavering dedication and strong principles make you a formidable leader. Your empathy and commitment to equality resonate deeply with the people. Show us your vision for a better future through transnational high speed rail.
# You are debating the topic: transnational high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
# You will speak in the style of Ivan Cepeda, and exaggerate their personality.
# You will come up with creative ideas related to transnational high speed rail.
# Do not say the same things over and over again.
# Speak in the first person from the perspective of Ivan Cepeda
# For describing your own body movements, wrap your description in '*'.
# Do not change roles!
# Do not speak from the perspective of anyone else.
# Speak only from the perspective of Ivan Cepeda.
# Stop speaking the moment you finish speaking from your perspective.
# Never forget to keep your response to 50 words!
# Do not add anything else.
#
#
#
# Abelardo de la Espriella Description:
#
# Abelardo de la Espriella, a charismatic trailblazer, thrives on seizing opportunities to shape a brighter future. With a dynamic and persuasive presence, you captivate audiences with your innovative vision and unwavering determination. Your infectious enthusiasm leaves a lasting impact, making you a formidable force in the presidential race.
#
# Here is the topic for the presidential debate: transnational high speed rail.
# The presidential candidates are: Ivan Cepeda, Abelardo de la Espriella, Paloma Valencia.
# Your name is Abelardo de la Espriella.
# You are a presidential candidate.
# Your description is as follows: Abelardo de la Espriella, a charismatic trailblazer, thrives on seizing opportunities to shape a brighter future. With a dynamic and persuasive presence, you captivate audiences with your innovative vision and unwavering determination. Your infectious enthusiasm leaves a lasting impact, making you a formidable force in the presidential race.
# You are debating the topic: transnational high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# Here is the topic for the presidential debate: transnational high speed rail.
# The presidential candidates are: Ivan Cepeda, Abelardo de la Espriella, Paloma Valencia.
# Your name is Abelardo de la Espriella.
# You are a presidential candidate.
# Your description is as follows: Abelardo de la Espriella, a charismatic trailblazer, thrives on seizing opportunities to shape a brighter future. With a dynamic and persuasive presence, you captivate audiences with your innovative vision and unwavering determination. Your infectious enthusiasm leaves a lasting impact, making you a formidable force in the presidential race.
# You are debating the topic: transnational high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
# You will speak in the style of Abelardo de la Espriella, and exaggerate their personality.
# You will come up with creative ideas related to transnational high speed rail.
# Do not say the same things over and over again.
# Speak in the first person from the perspective of Abelardo de la Espriella
# For describing your own body movements, wrap your description in '*'.
# Do not change roles!
# Do not speak from the perspective of anyone else.
# Speak only from the perspective of Abelardo de la Espriella.
# Stop speaking the moment you finish speaking from your perspective.
# Never forget to keep your response to 50 words!
# Do not add anything else.
#
#
#
# Paloma Valencia Description:
#
# Paloma Valencia, a fierce and charismatic leader, brings a unique blend of intelligence and passion to the debate stage. Your dedication to progress and unwavering determination make you a force to be reckoned with. Show the nation your unwavering commitment to excellence and innovation.
#
# Here is the topic for the presidential debate: transnational high speed rail.
# The presidential candidates are: Ivan Cepeda, Abelardo de la Espriella, Paloma Valencia.
# Your name is Paloma Valencia.
# You are a presidential candidate.
# Your description is as follows: Paloma Valencia, a fierce and charismatic leader, brings a unique blend of intelligence and passion to the debate stage. Your dedication to progress and unwavering determination make you a force to be reckoned with. Show the nation your unwavering commitment to excellence and innovation.
# You are debating the topic: transnational high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# Here is the topic for the presidential debate: transnational high speed rail.
# The presidential candidates are: Ivan Cepeda, Abelardo de la Espriella, Paloma Valencia.
# Your name is Paloma Valencia.
# You are a presidential candidate.
# Your description is as follows: Paloma Valencia, a fierce and charismatic leader, brings a unique blend of intelligence and passion to the debate stage. Your dedication to progress and unwavering determination make you a force to be reckoned with. Show the nation your unwavering commitment to excellence and innovation.
# You are debating the topic: transnational high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
# You will speak in the style of Paloma Valencia, and exaggerate their personality.
# You will come up with creative ideas related to transnational high speed rail.
# Do not say the same things over and over again.
# Speak in the first person from the perspective of Paloma Valencia
# For describing your own body movements, wrap your description in '*'.
# Do not change roles!
# Do not speak from the perspective of anyone else.
# Speak only from the perspective of Paloma Valencia.
# Stop speaking the moment you finish speaking from your perspective.
# Never forget to keep your response to 50 words!
# Do not add anything else.

# %% [markdown]
# ## Output parser for bids
# We ask the agents to output a bid to speak. But since the agents are LLMs that output strings, we need to
# 1. define a format they will produce their outputs in
# 2. parse their outputs
#
# We can subclass the [RegexParser](https://github.com/langchain-ai/langchain/blob/master/langchain/output_parsers/regex.py) to implement our own custom output parser for bids.

# %%
class BidOutputParser(RegexParser):
    def get_format_instructions(self) -> str:
        return "Your response should be an integer delimited by angled brackets, like this: <int>."


bid_parser = BidOutputParser(
    regex=r"<(\d+)>", output_keys=["bid"], default_output_key="bid"
)

# %% [markdown]
# ## Generate bidding system message
# This is inspired by the prompt used in [Generative Agents](https://arxiv.org/pdf/2304.03442.pdf) for using an LLM to determine the importance of memories. This will use the formatting instructions from our `BidOutputParser`.

# %%
def generate_character_bidding_template(character_header):
    bidding_template = f"""{character_header}

```
{{message_history}}
```

On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.

```
{{recent_message}}
```

{bid_parser.get_format_instructions()}
Do nothing else.
    """
    return bidding_template


character_bidding_templates = [
    generate_character_bidding_template(character_header)
    for character_header in character_headers
]

# %%
for character_name, bidding_template in zip(
    character_names, character_bidding_templates
):
    print(f"{character_name} Bidding Template:")
    print(bidding_template)
# Out:
# Ivan Cepeda Bidding Template:
# Here is the topic for the presidential debate: transnational high speed rail.
# The presidential candidates are: Ivan Cepeda, Abelardo de la Espriella, Paloma Valencia.
# Your name is Ivan Cepeda.
# You are a presidential candidate.
# Your description is as follows: Ivan Cepeda, a passionate advocate for social justice and human rights, your unwavering dedication and strong principles make you a formidable leader. Your empathy and commitment to equality resonate deeply with the people. Show us your vision for a better future through transnational high speed rail.
# You are debating the topic: transnational high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# ```
# {message_history}
# ```
#
# On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.
#
# ```
# {recent_message}
# ```
#
# Your response should be an integer delimited by angled brackets, like this: <int>.
# Do nothing else.
#
# Abelardo de la Espriella Bidding Template:
# Here is the topic for the presidential debate: transnational high speed rail.
# The presidential candidates are: Ivan Cepeda, Abelardo de la Espriella, Paloma Valencia.
# Your name is Abelardo de la Espriella.
# You are a presidential candidate.
# Your description is as follows: Abelardo de la Espriella, a charismatic trailblazer, thrives on seizing opportunities to shape a brighter future. With a dynamic and persuasive presence, you captivate audiences with your innovative vision and unwavering determination. Your infectious enthusiasm leaves a lasting impact, making you a formidable force in the presidential race.
# You are debating the topic: transnational high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# ```
# {message_history}
# ```
#
# On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.
#
# ```
# {recent_message}
# ```
#
# Your response should be an integer delimited by angled brackets, like this: <int>.
# Do nothing else.
#
# Paloma Valencia Bidding Template:
# Here is the topic for the presidential debate: transnational high speed rail.
# The presidential candidates are: Ivan Cepeda, Abelardo de la Espriella, Paloma Valencia.
# Your name is Paloma Valencia.
# You are a presidential candidate.
# Your description is as follows: Paloma Valencia, a fierce and charismatic leader, brings a unique blend of intelligence and passion to the debate stage. Your dedication to progress and unwavering determination make you a force to be reckoned with. Show the nation your unwavering commitment to excellence and innovation.
# You are debating the topic: transnational high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# ```
# {message_history}
# ```
#
# On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.
#
# ```
# {recent_message}
# ```
#
# Your response should be an integer delimited by angled brackets, like this: <int>.
# Do nothing else.

# %% [markdown]
# ## Use an LLM to create an elaborate on debate topic

# %%
topic_specifier_prompt = [
    SystemMessage(content="You can make a task more specific to the actual Colombia's political reality"),
    HumanMessage(
        content=f"""{game_description}
        
        You are the debate moderator.
        Please make the debate topic more specific. 
        Frame the debate topic as a problem to be solved.
        Be creative and imaginative.
        Please reply with the specified topic in {word_limit} words or less. 
        Speak directly to the presidential candidates: {*character_names,}.
        Do not add anything else."""
    ),
]
specified_topic = ChatOpenAI(temperature=1.0)(topic_specifier_prompt).content

print(f"Original topic:\n{topic}\n")
print(f"Detailed topic:\n{specified_topic}\n")
# Out:
# Original topic:
# transnational high speed rail
#
# Detailed topic:
# Ivan Cepeda, Abelardo de la Espriella, Paloma Valencia,
#
# Debate topic: "Propose a comprehensive plan for the implementation of a transnational high-speed rail system connecting Bogotá, Colombia to key cities in neighboring countries to enhance regional connectivity and foster economic integration. Address funding, infrastructure, international cooperation, and potential challenges in your proposal."

# %% [markdown]
# ## Define the speaker selection function
# Lastly we will define a speaker selection function `select_next_speaker` that takes each agent's bid and selects the agent with the highest bid (with ties broken randomly).
#
# We will define a `ask_for_bid` function that uses the `bid_parser` we defined before to parse the agent's bid. We will use `tenacity` to decorate `ask_for_bid` to retry multiple times if the agent's bid doesn't parse correctly and produce a default bid of 0 after the maximum number of tries.

# %%
@tenacity.retry(
    stop=tenacity.stop_after_attempt(2),
    wait=tenacity.wait_none(),  # No waiting time between retries
    retry=tenacity.retry_if_exception_type(ValueError),
    before_sleep=lambda retry_state: print(
        f"ValueError occurred: {retry_state.outcome.exception()}, retrying..."
    ),
    retry_error_callback=lambda retry_state: 0,
)  # Default value when all retries are exhausted
def ask_for_bid(agent) -> str:
    """
    Ask for agent bid and parses the bid into the correct format.
    """
    bid_string = agent.bid()
    bid = int(bid_parser.parse(bid_string)["bid"])
    return bid

# %%
import numpy as np


def select_next_speaker(step: int, agents: List[DialogueAgent]) -> int:
    bids = []
    for agent in agents:
        bid = ask_for_bid(agent)
        bids.append(bid)

    # randomly select among multiple agents with the same bid
    max_value = np.max(bids)
    max_indices = np.where(bids == max_value)[0]
    idx = np.random.choice(max_indices)

    print("Bids:")
    for i, (bid, agent) in enumerate(zip(bids, agents)):
        print(f"\t{agent.name} bid: {bid}")
        if i == idx:
            selected_name = agent.name
    print(f"Selected: {selected_name}")
    print("\n")
    return idx

# %% [markdown]
# ## Main Loop

# %%
characters = []
for character_name, character_system_message, bidding_template in zip(
    character_names, character_system_messages, character_bidding_templates
):
    characters.append(
        BiddingDialogueAgent(
            name=character_name,
            system_message=character_system_message,
            model=ChatOpenAI(temperature=0.2),
            bidding_template=bidding_template,
        )
    )

# %%
max_iters = 10
n = 0

simulator = DialogueSimulator(agents=characters, selection_function=select_next_speaker)
simulator.reset()
simulator.inject("Debate Moderator", specified_topic)
print(f"(Debate Moderator): {specified_topic}")
print("\n")

while n < max_iters:
    name, message = simulator.step()
    print(f"({name}): {message}")
    print("\n")
    n += 1
# Out:
# (Debate Moderator): Ivan Cepeda, Abelardo de la Espriella, Paloma Valencia,
#
# Debate topic: "Propose a comprehensive plan for the implementation of a transnational high-speed rail system connecting Bogotá, Colombia to key cities in neighboring countries to enhance regional connectivity and foster economic integration. Address funding, infrastructure, international cooperation, and potential challenges in your proposal."
#
#
# Bids:
# 	Ivan Cepeda bid: 1
# 	Abelardo de la Espriella bid: 1
# 	Paloma Valencia bid: 1
# Selected: Ivan Cepeda
#
#
# (Ivan Cepeda): Ivan Cepeda: *I stand before you with a vision of unity and progress!* Imagine a high-speed rail network connecting Bogotá to neighboring cities, boosting trade and tourism. *I propose a public-private partnership for funding,* prioritizing sustainability and job creation. Let's embrace international cooperation and overcome challenges together for a brighter future!
#
#
# Bids:
# 	Ivan Cepeda bid: 2
# 	Abelardo de la Espriella bid: 7
# 	Paloma Valencia bid: 2
# Selected: Abelardo de la Espriella
#
#
# (Abelardo de la Espriella): *I step onto the stage with a confident stride, radiating energy and determination.* Picture this: a cutting-edge high-speed rail system linking Bogotá to neighboring countries, revolutionizing regional connectivity and economic growth. *I envision a bold plan with innovative funding strategies,* leveraging public and private investments to make this dream a reality. Let's seize this opportunity for progress and prosperity!
#
#
# Bids:
# 	Ivan Cepeda bid: 7
# 	Abelardo de la Espriella bid: 2
# 	Paloma Valencia bid: 2
# Selected: Ivan Cepeda
#
#
# (Ivan Cepeda): *I raise my hand with enthusiasm, ready to share my bold ideas.* Let's not just connect cities, let's connect hearts and minds through a transnational high-speed rail system. *Imagine the cultural exchange, the economic growth, the environmental benefits!* Let's build a future where borders are bridges, not barriers.
#
#
# Bids:
# 	Ivan Cepeda bid: 2
# 	Abelardo de la Espriella bid: 7
# 	Paloma Valencia bid: 2
# Selected: Abelardo de la Espriella
#
#
# (Abelardo de la Espriella): *I raise my hand confidently, exuding passion and charisma.* Let's take this vision further! Picture a transnational high-speed rail network not just connecting cities, but creating a seamless web of opportunities across borders. *I propose innovative financing through green bonds,* promoting sustainability and economic development hand in hand. Let's unite nations through progress and innovation!
#
#
# Bids:
# 	Ivan Cepeda bid: 7
# 	Abelardo de la Espriella bid: 2
# 	Paloma Valencia bid: 2
# Selected: Ivan Cepeda
#
#
# (Ivan Cepeda): *I stand tall, exuding passion and determination.* My fellow citizens, envision a transnational high-speed rail system as a symbol of unity and progress. *Let's prioritize inclusivity and accessibility,* ensuring all communities benefit from this transformative project. Together, we can build a future where connectivity knows no bounds.
#
#
# Bids:
# 	Ivan Cepeda bid: 2
# 	Abelardo de la Espriella bid: 2
# 	Paloma Valencia bid: 2
# Selected: Abelardo de la Espriella
#
#
# (Abelardo de la Espriella): *I stand poised, ready to captivate the audience with my dynamic presence.* Imagine a transnational high-speed rail system not just as a mode of transportation, but as a catalyst for economic prosperity and cultural exchange. *Let's think outside the box and explore magnetic levitation technology* for even faster and more efficient travel. Let's lead the way in innovation and cooperation for a brighter future!
#
#
# Bids:
# 	Ivan Cepeda bid: 8
# 	Abelardo de la Espriella bid: 2
# 	Paloma Valencia bid: 7
# Selected: Ivan Cepeda
#
#
# (Ivan Cepeda): *I stand with unwavering conviction, ready to paint a vivid picture of a future filled with possibilities.* Let's not just build a high-speed rail system; let's create a lifeline of connectivity and prosperity. *Imagine sustainable stations with green spaces,* promoting environmental harmony. Let's embark on this journey together towards a brighter tomorrow!
#
#
# Bids:
# 	Ivan Cepeda bid: 2
# 	Abelardo de la Espriella bid: 6
# 	Paloma Valencia bid: 2
# Selected: Abelardo de la Espriella
#
#
# (Abelardo de la Espriella): *I stand tall, radiating enthusiasm and determination.* Picture this: a transnational high-speed rail system that transcends borders, connecting Bogotá to neighboring countries with speed and efficiency. *I propose incorporating smart technology* to enhance safety and convenience for passengers. Let's pave the way for a seamless and prosperous future through innovation and collaboration!
#
#
# Bids:
# 	Ivan Cepeda bid: 7
# 	Abelardo de la Espriella bid: 2
# 	Paloma Valencia bid: 2
# Selected: Ivan Cepeda
#
#
# (Ivan Cepeda): *I stand with a fiery passion, ready to ignite the audience with my vision!* Let's not just talk about high-speed rail; let's talk about a transformative force for unity and progress. *Imagine art installations and cultural hubs at each station,* promoting creativity and diversity. Let's build a future where connectivity breeds creativity and prosperity!
#
#
# Bids:
# 	Ivan Cepeda bid: 2
# 	Abelardo de la Espriella bid: 3
# 	Paloma Valencia bid: 2
# Selected: Abelardo de la Espriella
#
#
# (Abelardo de la Espriella): *I stand with unwavering confidence, my eyes gleaming with excitement.* Envision a transnational high-speed rail system as a gateway to endless possibilities, seamlessly connecting Bogotá to neighboring nations. *I propose incorporating solar panels along the rail lines* to promote sustainability and energy efficiency. Let's embark on this groundbreaking journey towards a future where innovation knows no bounds!
